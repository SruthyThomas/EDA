# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
data=pd.read_csv("myexcel.csv")
data
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # To check number of null values in the given dataset

# %%
##To check number of null values in the given dataset
data.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# # Finding the mode of Salary column

# %%
data.Salary.mode()
# Out:
# 0    947276.0
# Name: Salary, dtype: float64

# %% [markdown]
# # Imputation of Salary column   using mode:

# %%
newdata=data.fillna(data['Salary'].mode()[0])
newdata
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # Checking whether null values present in  Salary column

# %%
newdata['Salary'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Replacing Height column with random values

# %%
value=np.random.randint(low=150,high=181,size=(458,7))
newdata['Height']=value
newdata
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     160     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     152     235
# 2     John Holland  Boston Celtics      30       SG   27     152     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     152     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     156     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     160     203
# 454      Raul Neto       Utah Jazz      25       PG   24     180     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     167     256
# 456    Jeff Withey       Utah Jazz      24        C   26     170     231
# 457       Priyanka       Utah Jazz      34        C   25     163     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
count=newdata.Team.value_counts()
print(count)
names=count.index
sizes=count.values
plt.figure(figsize=(10,10))
plt.pie(sizes,labels=names,autopct='%.1f%%')
plt.title("Piechart")
plt.show()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %% [markdown]
# # observations:
# From the above piechart it is evident that more number of members present in  New Orleans Pelicans.Second position in terms of number of members is owned by Memphis Grizzlies  .

# %% [markdown]
# # Segregate the employees w.r.t different positions.

# %%
groups=newdata.groupby(['Position','Name'])
groups.first()
# Out:
#                                           Team  Number  Age  Height  Weight  \
# Position Name
# C        Al Horford              Atlanta Hawks      15   30     155     245
#          Al Jefferson        Charlotte Hornets      25   31     155     289
#          Alan Williams            Phoenix Suns      15   23     155     260
#          Alex Len                 Phoenix Suns      21   22     155     260
#          Alexis Ajinca    New Orleans Pelicans      42   28     155     248
# ...                                        ...     ...  ...     ...     ...
# SG       Tyreke Evans     New Orleans Pelicans       1   26     155     220
#          Victor Oladipo          Orlando Magic       5   24     155     210
#          Vince Carter        Memphis Grizzlies      15   39     155     220
#          Wayne Ellington         Brooklyn Nets      21   28     155     200
#          Wesley Matthews      Dallas Mavericks      23   29     155     220
#
# ...

# %%
newdata.groupby(['Position'],as_index=False)['Name'].sum()
# Out:
#   Position                                               Name
# 0        C  Kelly OlynykJared SullingerTyler ZellerBrook L...
# 1       PF  Jonas JerebkoAmir JohnsonJordan MickeyChris Mc...
# 2       PG  Avery BradleyTerry RozierMarcus SmartIsaiah Th...
# 3       SF  Jae CrowderThanasis AntetokounmpoCarmelo Antho...
# 4       SG  John HollandR.J. HunterEvan TurnerJames YoungB...

# %%
newdata.Position.value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# # observations
# More number of members belongs to SG position.Second position owned by PF position and least number number of members in C position.

# %% [markdown]
# # Find from which age group most of the employees belong to.

# %%
plt.figure(figsize=(5,5))
plt.hist(newdata['Age'])
plt.yticks(np.arange(0,200,20))
plt.xticks(np.arange(0,50,4))
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # observations
# Most of the members belongs to the age group 24 to 25.

# %%
newdata.Age.value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %% [markdown]
# # Find out under which team and position, spending in terms of salary is high.

# %%
result=newdata.groupby(['Team','Position'],as_index=False)['Salary'].max().sort_values(by="Salary",ascending=False)
print(result.iloc[0])
# Out:
# Team        Los Angeles Lakers
# Position                    SF
# Salary              25000000.0
# Name: 67, dtype: object

# %% [markdown]
# # observations:
# Team  Los Angeles Lakers ,position SF ,spending interms of salary is high.

# %% [markdown]
# # Find if there is any correlation between age and salary , represent it visually

# %%
newdata.Salary.value_counts()
# Out:
# Salary
# 947276.0      43
# 845059.0      18
# 525093.0      13
# 981348.0       6
# 16407500.0     5
#               ..
# 2100000.0      1
# 1252440.0      1
# 2891760.0      1
# 3272091.0      1
# 900000.0       1
# Name: count, Length: 309, dtype: int64

# %%
import matplotlib.ticker as ticker
x = newdata['Age']
y = newdata['Salary']  

# Create a scatterplot
plt.scatter(x, y)

# Define a function to format y-axis labels
def lakhs_millions_formatter(x, pos):
    if x < 1000000:
        return f'{x/100000:.0f}L'  # Format in lakhs
    else:
        return f'{x/1000000:.1f}M'  # Format in millions

# Apply the custom formatter to the y-axis
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lakhs_millions_formatter))
plt.title("Salary and Age Correlation")
plt.xlabel("Age")
plt.ylabel("Salary")

# Show the plot
plt.show()

# %%
#finding correlation coefficient  between Age and Salary
newdata['Age'].corr( newdata['Salary'] )
# Out:
# 0.20653501683058964

# %% [markdown]
# # obsevations:
# Correlation Coefficient is 0.20653501683058964.There is no correalation between Age and Salary.

# %% [markdown]
# # conclusions:
# 1) More number of members present in New Orleans Pelicans.Second position in terms of number of members is owned by Memphis Grizzlies .
# 2) More number of members belongs to SG position.Second position owned by PF position and least number number of members in C position.
# 3) Most of the members belongs to the age group 24 to 25.
# 4) Team Los Angeles Lakers ,position SF ,spending interms of salary is high.
# 5) Correlation Coefficient between Age and Salary  is 0.20653501683058964.There is no correalation between Age and Salary.
